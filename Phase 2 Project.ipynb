# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import collections

# Set styling for our plots
plt.style.use('ggplot')
sns.set(style="whitegrid")

# For reproducibility
np.random.seed(42)

# %%
# Simulate 1000 dice rolls
dice_rolls = np.random.randint(1, 7, size=1000)

# Count the frequency of each outcome
dice_counter = collections.Counter(dice_rolls)

# Calculate the probability of each outcome
dice_pmf = {k: v/len(dice_rolls) for k, v in sorted(dice_counter.items())}

# Visualize the PMF
plt.figure(figsize=(10, 6))
plt.bar(dice_pmf.keys(), dice_pmf.values())
plt.title('Probability Mass Function of Dice Rolls')
plt.xlabel('Dice Value')
plt.ylabel('Probability')
plt.xticks(range(1, 7))
plt.show()
